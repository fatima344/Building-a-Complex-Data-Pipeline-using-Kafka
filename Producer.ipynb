# %%
from kafka import KafkaProducer
import json
from json import dumps
from time import sleep

# %%
#producer = KafkaProducer(bootstrap_servers=['localhost:9092'],value_serializer=lambda x: dumps(x).encode('utf-8'))
producer = KafkaProducer(bootstrap_servers=['localhost:9092'], value_serializer=lambda x: json.dumps(x).encode('utf-8'))

# %%
import yfinance as yf

# %%
data = yf.download('AAPL,TSLA,NFLX',period='7d',interval='1h')
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#                             Adj Close                               Close  \
#                                  AAPL        NFLX        TSLA        AAPL
# Datetime
# 2023-04-03 09:30:00-04:00  165.360001  345.440002  196.949997  165.360001
# 2023-04-03 10:30:00-04:00  164.630005  345.829987  194.670105  164.630005
# 2023-04-03 11:30:00-04:00  164.600006  345.970001  195.562500  164.600006
# 2023-04-03 12:30:00-04:00  164.550003  345.654999  193.229904  164.550003
# 2023-04-03 13:30:00-04:00  164.913498  345.714386  193.420105  164.913498
# 2023-04-03 14:30:00-04:00  165.695007  347.170013  194.350098  165.695007
# 2023-04-03 15:30:00-04:00  166.100006  348.239990  194.699997  166.100006
# 2023-04-04 09:30:00-04:00  166.250000  346.160004  193.720001  166.250000
# 2023-04-04 10:30:00-04:00  166.149994  347.329987  191.228302  166.149994
# 2023-04-04 11:30:00-04:00  165.830002  346.105011  191.639297  165.830002
# ...

# %%
rows=data.shape[0]

# %% [markdown]
# Producer 1

# %%
for i in range(0,rows):
    stocks1 = data.iloc[[i]].to_dict(orient="records")[0]
    stocks2 = dict((':'.join(k),v) for k,v in stocks1.items())
    producer.send('test1',value=stocks2)
    sleep(2)

# %%
for i in range(0,rows):
    stocks1 = data.iloc[[i]].to_dict(orient="records")[0]
    stocks2 = dict((':'.join(k),v) for k,v in stocks1.items())
    producer.send('test2',value=stocks2)
    sleep(2)

# %% [markdown]
# Producer 2

# %%
for i in range(0,rows):
    stocks1 = data.iloc[[i]].to_dict(orient="records")[0]
    stocks2 = dict((':'.join(k),v) for k,v in stocks1.items())
    producer.send('test3',value=stocks2)
    sleep(2)
